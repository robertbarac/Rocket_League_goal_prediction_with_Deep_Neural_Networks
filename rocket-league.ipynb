# %%
import os
import gc
import pandas as pd
import tensorflow as tf
import numpy as np

from tensorflow import keras
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.models import Sequential

from sklearn.model_selection import train_test_split

# %%
pd.options.display.max_columns = None

# %%
data_path = '/kaggle/input/tabular-playground-series-oct-2022/'
feather_path = '../input/rocket-league/'

# %%
train_dtypes_file = os.path.join(data_path, 'train_dtypes.csv')
test_dtypes_file = os.path.join(data_path, 'test_dtypes.csv')
sample_submission_file = os.path.join(data_path, 'sample_submission.csv')
sample_submission_file2 = os.path.join(data_path, 'sample_submission2.csv')
train_feather_file = os.path.join(feather_path, 'train.feather')
test_feather_file = os.path.join(feather_path, 'test.feather')

# %%
train_dtypes_df = pd.read_csv(train_dtypes_file)
test_dtypes_df = pd.read_csv(test_dtypes_file)
cols_dtypes = {k: v for (k, v) in zip(train_dtypes_df.column, train_dtypes_df.dtype)}

# %% [markdown]
# Ignoring the useless columns
# Lets see what columns we will not use to train.

# %%
[c for c in train_dtypes_df['column'] if c not in test_dtypes_df['column'].values]
# Out:
# ['game_num',
#  'event_id',
#  'event_time',
#  'player_scoring_next',
#  'team_scoring_next',
#  'team_A_scoring_within_10sec',
#  'team_B_scoring_within_10sec']

# %% [markdown]
# ## Feature Selection

# %%
targets = ['team_A_scoring_within_10sec', 'team_B_scoring_within_10sec']
useless_cols = ['event_id', 'ball_vel_x', 'ball_vel_y', 'ball_vel_z', 'p0_vel_x', 'p0_vel_y', 'p0_vel_z', 
                'p1_vel_x', 'p1_vel_y', 'p1_vel_z', 'p2_vel_x', 'p2_vel_y', 'p2_vel_z', 
                'p3_vel_x', 'p3_vel_y', 'p3_vel_z', 'p4_vel_x', 'p4_vel_y', 'p4_vel_z', 
                'p5_vel_x', 'p5_vel_y', 'p5_vel_z', 
                'boost0_timer', 'boost1_timer', 'boost2_timer', 
                'boost3_timer', 'boost4_timer', 'boost5_timer', 'team_A_scoring_within_10sec', 'team_B_scoring_within_10sec'
               ]
useless_cols2 = ['ball_vel_x', 'ball_vel_y', 'ball_vel_z', 'p0_vel_x', 'p0_vel_y', 'p0_vel_z', 
                'p1_vel_x', 'p1_vel_y', 'p1_vel_z', 'p2_vel_x', 'p2_vel_y', 'p2_vel_z', 
                'p3_vel_x', 'p3_vel_y', 'p3_vel_z', 'p4_vel_x', 'p4_vel_y', 'p4_vel_z', 
                'p5_vel_x', 'p5_vel_y', 'p5_vel_z', 
                 'boost0_timer', 'boost1_timer', 'boost2_timer', 
                'boost3_timer', 'boost4_timer', 'boost5_timer']
use_cols = [c for c in train_dtypes_df['column'] if c not in useless_cols]
features = test_dtypes_df['column'][1:].values # drop id

# %%
train_df = pd.read_feather(train_feather_file)

# %%
def eliminate_useless_columns(df, columns_list):
    df = df.drop(columns_list, axis=1, inplace=True)

# %%
def normalizer(df, columns, min_data, max_data):
    for column in columns:
        min_data = df[column].min()
        max_data = df[column].max()
        df[column] = (df[column] - min_data) / (max_data - min_data)
    return df, min_data, max_data

# %%
targets_df = pd.DataFrame()
targets_df['team_A_scoring_within_10sec'] = train_df['team_A_scoring_within_10sec']
targets_df['team_B_scoring_within_10sec'] = train_df['team_B_scoring_within_10sec']
#targets_df = targets_df[(targets_df['team_A_scoring_within_10sec']==1) | (targets_df['team_B_scoring_within_10sec']==1)]
gc.collect()
# Out:
# 0

# %%
train_df.fillna(0, inplace=True)
#train_df = train_df[(train_df['team_A_scoring_within_10sec']==1) | (train_df['team_B_scoring_within_10sec']==1)]
gc.collect()
# Out:
# 23

# %%
# prepariapplyng data
def prepare_data(df):

    # velocity value for 0-5 players and the ball
    for i in range(6):
        df[f'p{i}_vel'] = np.sqrt(
           df[f'p{i}_vel_x']**2+
           df[f'p{i}_vel_y']**2+
           df[f'p{i}_vel_z']**2)
    for i in range(6):
        df.drop([f'p{i}_vel_x'], axis=1, inplace=True)
        df.drop([f'p{i}_vel_y'], axis=1, inplace=True)
        df.drop([f'p{i}_vel_z'], axis=1, inplace=True)
        
    df['ball_vel'] = np.sqrt(
       df['ball_vel_x']**2+
       df['ball_vel_y']**2+
       df['ball_vel_z']**2)
    df.drop(['ball_vel_x', 'ball_vel_y', 'ball_vel_z'], axis=1, inplace=True)
    df.drop(['boost0_timer', 'boost1_timer', 'boost2_timer', 'boost3_timer', 'boost4_timer', 'boost5_timer'], axis=1, inplace=True)
    
    # distances from players to ball
    for i in range(6):
        df[f'p{i}_dist_ball'] = np.sqrt(
           (df[f'p{i}_pos_x']-df['ball_pos_x'])**2+
           (df[f'p{i}_pos_y']-df['ball_pos_y'])**2+
           (df[f'p{i}_pos_z']-df['ball_pos_z'])**2)
    # mean distance from team A or team B to the ball
    df['mean_dist_teamA_to_ball'] = (df['p0_dist_ball']+ df['p1_dist_ball']+ df['p2_dist_ball'])/3
    df['mean_dist_teamB_to_ball'] = (df['p3_dist_ball']+ df['p4_dist_ball']+ df['p5_dist_ball'])/3

    # mean velocity for each team
    df['mean_vel_teamA'] = (df['p0_vel']+ df['p1_vel']+ df['p2_vel'])/3
    df['mean_vel_teamB'] = (df['p3_vel']+ df['p4_vel']+ df['p5_vel'])/3

    # mean boost for each team
    df['median_boost_A'] = (df['p0_boost'] + df['p1_boost'] + df['p2_boost']) / 3
    df['median_boost_B'] = (df['p3_boost'] + df['p4_boost'] + df['p5_boost']) / 3
    return df

# %%
train_df.drop(['event_id', 'team_A_scoring_within_10sec', 'team_B_scoring_within_10sec'], axis=1, inplace = True)
gc.collect()
# Out:
# 236

# %%
train_df = prepare_data(train_df)
gc.collect()
# Out:
# 13

# %%
train_df.head()
# Out:
#    ball_pos_x  ball_pos_y  ball_pos_z   p0_pos_x   p0_pos_y  p0_pos_z  \
# 0        -0.0         0.0      1.8548  41.804798 -51.924999    0.3402
# 1        -0.0         0.0      1.8548  42.261600 -52.451202    0.3402
# 2        -0.0         0.0      1.8548  43.227001 -54.054001    1.1466
# 3        -0.0         0.0      1.8548  43.898399 -55.225601    1.5936
# 4        -0.0         0.0      1.8548  44.960602 -57.087799    2.0720
#
#    p0_boost  p1_pos_x   p1_pos_y  p1_pos_z   p1_boost   p2_pos_x   p2_pos_y  \
# 0  33.34375   -5.0654 -75.519402    0.3402  27.328125 -39.654400 -49.894398
# 1  33.34375   -4.9298 -74.326401    0.4900  23.843750 -38.626202 -48.871803
# 2  33.34375   -4.6880 -72.959000    1.0820  23.140625 -36.345200 -47.016201
# 3  33.34375   -3.8408 -69.125801    1.9106  23.140625 -35.173599 -45.287998
# 4  33.34375   -3.2720 -66.594398    1.9814  23.140625 -34.066002 -43.518997
#
#    p2_pos_z   p2_boost  p3_pos_x   p3_pos_y  p3_pos_z  p3_boost   p4_pos_x  \
# 0    0.3402  22.343750    5.0604  75.532005    0.3402  33.34375 -41.766403
# 1    0.3402  30.625000    5.0110  74.772995    0.3402  33.34375 -42.407204
# 2    1.1346  26.890625    4.9168  73.767601    0.3402  33.34375 -43.778198
# 3    1.5598  23.375000    4.6906  71.631401    0.4394  31.00000 -44.919800
# 4    1.8632  19.843750    4.5010  69.921600    1.0822  27.46875 -46.170399
#
#     p4_pos_y  p4_pos_z  p4_boost   p5_pos_x   p5_pos_y  p5_pos_z   p5_boost  \
# 0  52.006401    0.3410  33.34375  39.757401  49.821602    0.3402  22.343750
# 1  52.622402    0.5944  33.34375  38.781399  48.761402    0.3402  30.625000
# 2  54.081402    1.6450  33.34375  36.503998  46.920601    1.0214  26.890625
# 3  55.525200    2.1334  33.34375  35.151798  44.873398    1.5286  23.375000
# 4  57.104401    2.2552  33.34375  33.584801  42.203400    1.9106  19.843750
#
#       p0_vel     p1_vel     p2_vel     p3_vel     p4_vel     p5_vel  ball_vel  \
# 0   7.434417   9.967111  12.458232   8.067610   7.690071  12.398498       0.0
# 1   9.157838  15.035421  16.159700   9.966599  11.653255  15.967882       0.0
# 2  13.024463  17.010210  21.310888  11.863656  20.903774  21.332428       0.0
# 3  22.081198  26.259382  31.118071  16.746733  20.673391  30.489305       0.0
# 4  21.858263  25.951704  32.038734  19.301310  20.159603  31.731245       0.0
#
#    p0_dist_ball  p1_dist_ball  p2_dist_ball  p3_dist_ball  p4_dist_ball  \
# 0     66.679390     75.704239     63.751205     75.716476     66.718735
# 1     67.375557     74.502213     62.311558     74.956024     67.594948
# 2     69.216400     73.113541     59.430759     73.946793     69.579971
# 3     70.547890     69.232445     57.343452     71.798767     71.420685
# 4     72.667183     66.674850     55.266586     70.070580     73.435539
#
#    p5_dist_ball  mean_dist_teamA_to_ball  mean_dist_teamB_to_ball  \
# 0     63.758423                68.711617                68.731209
# 1     62.321468                68.063110                68.290810
# 2     59.454006                67.253563                67.660255
# 3     57.003307                65.707924                66.740921
# 4     53.935787                64.869545                65.813972
#
#    mean_vel_teamA  mean_vel_teamB  median_boost_A  median_boost_B
# 0        9.953254        9.385392       27.671875       29.671875
# 1       13.450986       12.529246       29.265625       32.437500
# 2       17.115187       18.033285       27.796875       31.187500
# 3       26.486216       22.636477       26.625000       29.250000
# 4       26.616234       23.730721       25.453125       26.875000

# %%
min_data = None
max_data = None

# %%
lista_columnas_normalizar = ['ball_pos_x', 'ball_pos_y', 'ball_pos_z', 'p0_pos_x', 'p0_pos_y', 'p0_pos_z', 'p1_pos_x', 'p1_pos_y', 'p1_pos_z', 'p2_pos_x', 'p2_pos_y', 'p2_pos_z', 'p3_pos_x', 'p3_pos_y', 'p3_pos_z', 'p4_pos_x', 'p4_pos_y', 'p4_pos_z', 'p5_pos_x', 'p5_pos_y', 'p5_pos_z', 'p0_boost', 'p1_boost', 'p2_boost', 'p3_boost', 'p4_boost', 'p5_boost', 'p0_vel', 'p1_vel', 'p2_vel', 'p3_vel', 'p4_vel', 'p5_vel', 'ball_vel', 'p0_dist_ball', 'p1_dist_ball', 'p2_dist_ball', 'p3_dist_ball', 'p4_dist_ball', 'p5_dist_ball', 'mean_dist_teamA_to_ball', 'mean_dist_teamB_to_ball', 'mean_vel_teamA', 'mean_vel_teamB', 'median_boost_A', 'median_boost_B']

# %%
train_df, min_data, max_data = normalizer(train_df, lista_columnas_normalizar, min_data, max_data)

# %%
test_df = pd.read_feather(test_feather_file)

# %%
train_df.shape
# Out:
# (21198036, 46)

# %%
test_df.shape
# Out:
# (701143, 54)

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 701143 entries, 0 to 701142
# Data columns (total 54 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ball_pos_x    701143 non-null  float32
#  1   ball_pos_y    701143 non-null  float32
#  2   ball_pos_z    701143 non-null  float32
#  3   ball_vel_x    701143 non-null  float32
#  4   ball_vel_y    701143 non-null  float32
#  5   ball_vel_z    701143 non-null  float32
#  6   p0_pos_x      694843 non-null  float32
#  7   p0_pos_y      694843 non-null  float32
#  8   p0_pos_z      694843 non-null  float32
#  9   p0_vel_x      694843 non-null  float32
#  10  p0_vel_y      694843 non-null  float32
#  11  p0_vel_z      694843 non-null  float32
#  12  p0_boost      694843 non-null  float16
#  13  p1_pos_x      694965 non-null  float32
#  14  p1_pos_y      694965 non-null  float32
#  15  p1_pos_z      694965 non-null  float32
#  16  p1_vel_x      694965 non-null  float32
#  17  p1_vel_y      694965 non-null  float32
#  18  p1_vel_z      694965 non-null  float32
#  19  p1_boost      694965 non-null  float16
#  20  p2_pos_x      694976 non-null  float32
#  21  p2_pos_y      694976 non-null  float32
#  22  p2_pos_z      694976 non-null  float32
#  23  p2_vel_x      694976 non-null  float32
#  24  p2_vel_y      694976 non-null  float32
#  25  p2_vel_z      694976 non-null  float32
#  26  p2_boost      694976 non-null  float16
#  27  p3_pos_x      694924 non-null  float32
#  28  p3_pos_y      694924 non-null  float32
#  29  p3_pos_z      694924 non-null  float32
#  30  p3_vel_x      694924 non-null  float32
#  31  p3_vel_y      694924 non-null  float32
#  32  p3_vel_z      694924 non-null  float32
#  33  p3_boost      694924 non-null  float16
#  34  p4_pos_x      694863 non-null  float32
#  35  p4_pos_y      694863 non-null  float32
#  36  p4_pos_z      694863 non-null  float32
#  37  p4_vel_x      694863 non-null  float32
#  38  p4_vel_y      694863 non-null  float32
#  39  p4_vel_z      694863 non-null  float32
#  40  p4_boost      694863 non-null  float16
#  41  p5_pos_x      694941 non-null  float32
#  42  p5_pos_y      694941 non-null  float32
#  43  p5_pos_z      694941 non-null  float32
#  44  p5_vel_x      694941 non-null  float32
#  45  p5_vel_y      694941 non-null  float32
#  46  p5_vel_z      694941 non-null  float32
#  47  p5_boost      694941 non-null  float16
#  48  boost0_timer  701143 non-null  float16
#  49  boost1_timer  701143 non-null  float16
#  50  boost2_timer  701143 non-null  float16
#  51  boost3_timer  701143 non-null  float16
#  52  boost4_timer  701143 non-null  float16
#  53  boost5_timer  701143 non-null  float16
# dtypes: float16(12), float32(42)
# memory usage: 128.4 MB

# %%
test_df.fillna(0, inplace=True)

# %%
test_df.head()
# Out:
#    ball_pos_x  ball_pos_y  ball_pos_z  ball_vel_x  ball_vel_y  ball_vel_z  \
# 0  -56.270802   29.510000   17.348600   24.499399   -1.311400   11.006801
# 1    2.852800   70.195999    8.949000   -8.152200  -65.577202   18.536400
# 2   52.366402  -98.036797   14.249001   -2.000000  -45.291401  -15.423400
# 3   36.365402   53.961403   23.161798   24.829399  -10.328600   -0.918000
# 4  -23.262400  -53.391003   21.209600   -1.667600  -24.778799    3.481200
#
#     p0_pos_x    p0_pos_y  p0_pos_z   p0_vel_x  p0_vel_y   p0_vel_z  p0_boost  \
# 0 -35.776199   73.136803    1.2480  18.386999   -5.1350 -21.402800   0.00000
# 1  22.926001   87.543800    0.3396 -41.954800  -18.7950   0.011400   0.78418
# 2  51.288998 -102.055595    6.3570   8.638000    0.3404  19.509399  37.18750
# 3  16.424799    0.932800    0.3402  39.627602   18.2836   0.000000  88.31250
# 4 -19.681801  -93.913605    4.7832  -4.137600    0.8012  11.265600  54.12500
#
#     p1_pos_x   p1_pos_y  p1_pos_z   p1_vel_x   p1_vel_y  p1_vel_z  p1_boost  \
# 0 -72.905403  28.819399   11.7000 -19.212801  -1.810400    5.7040  49.40625
# 1   5.960200  59.600201    0.3400 -44.143398 -12.936601    0.0024  34.50000
# 2 -31.900600  31.375200    1.9754 -32.762001 -24.698999   -0.2908   0.00000
# 3 -39.392799  40.812000    0.3398  29.773998 -12.654400    0.0060  82.43750
# 4 -32.087200 -33.042599    6.3446 -15.919001  -3.791200   -3.0140  43.12500
#
#     p2_pos_x    p2_pos_y  p2_pos_z   p2_vel_x   p2_vel_y  p2_vel_z  \
# 0 -36.379200  -18.858400    0.3402 -45.022797  -5.577400    0.0042
# 1  69.736603  -11.253600    0.3402  -0.534000 -45.694801    0.0042
# 2   0.661600 -107.274406    0.3540  27.366798   1.222600   -0.0284
# 3   6.614800   84.760994    3.3024 -13.596200  35.463402  -25.9512
# 4 -61.132202  -81.612404    0.3398  23.880800 -26.558998    0.0092
#
#      p2_boost   p3_pos_x   p3_pos_y  p3_pos_z   p3_vel_x  p3_vel_y  p3_vel_z  \
# 0   87.812500  -3.435200  93.975403    0.3402 -27.262400   -2.5516    0.0050
# 1    0.000000   0.000000   0.000000    0.0000   0.000000    0.0000    0.0000
# 2   45.500000  40.266998 -35.871998    0.3402   2.058600  -45.0298    0.0042
# 3    2.744141 -45.288998  83.107803    0.3400 -43.536800   11.2418    0.0068
# 4  100.000000 -31.090801 -16.736601   14.4918 -12.585401   16.1012    6.9564
#
#    p3_boost  p4_pos_x    p4_pos_y   p4_pos_z   p4_vel_x   p4_vel_y   p4_vel_z  \
# 0  69.06250  -23.3904  101.715599  28.972601  25.478001  11.517600 -18.315401
# 1   0.00000   12.2516   86.967804   1.538200  27.584000 -26.174599  -0.292800
# 2  47.84375   51.2798  -93.799805  15.626801  -4.687200 -44.268200  -0.309000
# 3  36.09375   11.0128   53.168999  18.103600  -9.272200 -16.618799  -6.720800
# 4  58.03125  -36.6856   29.899399   0.373200 -16.562401 -34.652000   0.002000
#
#     p4_boost   p5_pos_x   p5_pos_y  p5_pos_z   p5_vel_x   p5_vel_y  p5_vel_z  \
# 0  83.125000 -51.055599  54.594200    0.3400   3.948400 -16.710800    0.0074
# 1  84.187500  39.126598  92.815002    0.3402 -15.496800 -14.876600    0.0050
# 2  23.140625  16.942600  38.711998    0.3402   0.905800 -27.413601    0.0042
# 3  49.031250  17.170799  93.164406    0.3402  -5.053200 -15.106999    0.0052
# 4  85.500000  63.796600 -15.374201    0.3402  22.200001  24.928001    0.0042
#
#    p5_boost  boost0_timer  boost1_timer  boost2_timer  boost3_timer  \
# 0   71.0000      0.000000     -3.263672     -6.132812     -6.875000
# 1   66.6875      0.000000     -1.615234     -5.968750     -5.503906
# 2   80.3750     -0.031586      0.000000      0.000000     -3.128906
# 3   96.0625     -6.429688     -4.089844     -7.832031     -5.761719
# 4    0.0000     -9.882812      0.000000     -0.445557     -0.491455
#
#    boost4_timer  boost5_timer
# 0     -7.015625     -3.230469
# 1      0.000000     -6.511719
# 2      0.000000     -3.677734
# 3      0.000000     -3.923828
# 4     -7.828125      0.000000

# %%
test_df = prepare_data(test_df)

# %%
test_df, _, _ = normalizer(test_df, lista_columnas_normalizar, min_data, max_data)

# %% [markdown]
# ### Split Data

# %%
per = 1
length_train = train_df.shape[0]

X_train, X_valid = train_df[:round(length_train*(1-per/100) - 1)], train_df[round(length_train*(1-per/100) - 1):]
Y_train, Y_valid = targets_df[:round(length_train*(1-per/100) - 1)], targets_df[round(length_train*(1-per/100) - 1):]
#X_train, X_val, Y_train, Y_val = train_test_split(train_df, targets_df, test_size=0.01, random_state=0)
del (train_df, targets_df)
gc.collect()
# Out:
# 9734

# %% [markdown]
# ## DNN Model

# %%
model = Sequential([
    Dense(128, activation='relu', input_shape = [X_train.shape[1]]),
    BatchNormalization(),
    Dropout(0.05),
    
    Dense(256, activation='relu'),    
    BatchNormalization(),
    Dropout(0.1),
    
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.15),
    
    Dense(128, activation='relu'),    
    BatchNormalization(),
    Dropout(0.2),
    
    Dense(2)
])
# Out:
# 2022-11-01 00:59:47.733165: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-01 00:59:47.739646: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-01 00:59:47.933862: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-01 00:59:47.934991: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-01 00:59:47.935814: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-01 00:59:47.936581: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-01 00:59:47.939982: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-01 00:59:48.180231: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-01 00:59:48.181101: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-01 00:59:48.181866: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-01 00:59:48.182632: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-01 00:59:48.183344: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-01 00:59:48.184068: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-01 00:59:51.509427: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-01 00:59:51.510442: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-01 00:59:51.511188: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-01 00:59:51.511929: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-01 00:59:51.512667: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-01 00:59:51.514789: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-11-01 00:59:51.519983: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-01 00:59:51.520671: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
model2 = Sequential([
    Dense(32, activation='relu', input_shape=[X_train.shape[1]]), 
    
    Dense(64, activation='relu'),
    Dropout(0.1), 
    
    Dense(128, activation='relu'),
    Dropout(0.3), 
    
    Dense(2) 
])

# %%
model.compile(optimizer='adam',
             loss='binary_crossentropy',
             metrics=['accuracy'])

# %%
model2.compile(optimizer='adam',
             loss='binary_crossentropy',
             metrics=['accuracy'])

# %%
history = model.fit(X_train, Y_train, 
              epochs=20, 
              steps_per_epoch=X_train.shape[0]//512, 
              batch_size=512,
              validation_data=(X_valid, Y_valid),
         )

# %%
history2 = model2.fit(X_train, Y_train, 
              epochs=16, 
              steps_per_epoch=X_train.shape[0]//512, 
              batch_size=512,
              validation_data=(X_valid, Y_valid),
         )
# Out:
# Epoch 1/16
# 4606/4606 [==============================] - 16s 3ms/step - loss: 0.5781 - accuracy: 0.7192 - val_loss: 0.5437 - val_accuracy: 0.7281
# Epoch 2/16
# 4606/4606 [==============================] - 16s 4ms/step - loss: 0.5477 - accuracy: 0.7334 - val_loss: 0.5408 - val_accuracy: 0.7245
# Epoch 3/16
# 4606/4606 [==============================] - 15s 3ms/step - loss: 0.5453 - accuracy: 0.7347 - val_loss: 0.5411 - val_accuracy: 0.7259
# Epoch 4/16
# 4606/4606 [==============================] - 16s 3ms/step - loss: 0.5347 - accuracy: 0.7390 - val_loss: 0.5498 - val_accuracy: 0.7334
# Epoch 5/16
# 4606/4606 [==============================] - 16s 3ms/step - loss: 0.5361 - accuracy: 0.7381 - val_loss: 0.5531 - val_accuracy: 0.7360
# Epoch 6/16
# 4606/4606 [==============================] - 16s 3ms/step - loss: 0.5570 - accuracy: 0.7296 - val_loss: 0.5362 - val_accuracy: 0.7358
# Epoch 7/16
# 4606/4606 [==============================] - 16s 3ms/step - loss: 0.5401 - accuracy: 0.7392 - val_loss: 0.5333 - val_accuracy: 0.7395
# Epoch 8/16
# 4606/4606 [==============================] - 16s 3ms/step - loss: 0.5447 - accuracy: 0.7356 - val_loss: 0.5408 - val_accuracy: 0.7359
# Epoch 9/16
# 4606/4606 [==============================] - 15s 3ms/step - loss: 0.5362 - accuracy: 0.7411 - val_loss: 0.5279 - val_accuracy: 0.7410
# Epoch 10/16
# 4606/4606 [==============================] - 15s 3ms/step - loss: 0.5269 - accuracy: 0.7448 - val_loss: 0.5308 - val_accuracy: 0.7415
# Epoch 11/16
# 4606/4606 [==============================] - 15s 3ms/step - loss: 0.5319 - accuracy: 0.7420 - val_loss: 0.5357 - val_accuracy: 0.7375
# Epoch 12/16
# 4606/4606 [==============================] - 15s 3ms/step - loss: 0.5300 - accuracy: 0.7423 - val_loss: 0.5354 - val_accuracy: 0.7326
# Epoch 13/16
# 4606/4606 [==============================] - 16s 3ms/step - loss: 0.5331 - accuracy: 0.7406 - val_loss: 0.5485 - val_accuracy: 0.7284
# Epoch 14/16
# 4606/4606 [==============================] - 15s 3ms/step - loss: 0.5331 - accuracy: 0.7409 - val_loss: 0.5271 - val_accuracy: 0.7326
# Epoch 15/16
# 4606/4606 [==============================] - 16s 3ms/step - loss: 0.5414 - accuracy: 0.7373 - val_loss: 0.5362 - val_accuracy: 0.7360
# Epoch 16/16
# 4606/4606 [==============================] - 15s 3ms/step - loss: 0.5309 - accuracy: 0.7437 - val_loss: 0.5261 - val_accuracy: 0.7396

# %%
predictions = model.predict(test_df)
score = tf.nn.softmax(predictions)

# %%
predictions2 = model2.predict(test_df)
score2 = tf.nn.softmax(predictions2)

# %%
ss = pd.read_csv(sample_submission_file)
ss['team_A_scoring_within_10sec'] = score[:,0]
ss['team_B_scoring_within_10sec'] = score[:,1]
ss.to_csv('Submission.csv', index=False)
ss.head()
# Out:
#    id  team_A_scoring_within_10sec  team_B_scoring_within_10sec
# 0   0                     0.546195                     0.453805
# 1   1                     0.625528                     0.374472
# 2   2                     0.326114                     0.673886
# 3   3                     0.492999                     0.507001
# 4   4                     0.372334                     0.627666
